# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
CIFAR100 = tf.keras.datasets.cifar100

(x_train , y_train),(x_test , y_test) = CIFAR100.load_data()
x_train , x_test = x_train / 255.0 , x_test / 255.0

# %%
x_train[0].shape
# Out:
# (32, 32, 3)

# %%
def show(data , labels):
  plt.subplots(figsize=(12,12))
  for i in range(12):
    plt.subplot(3,4, i+1)
    k = np.random.randint(0 , data.shape[0])
    plt.title(labels[k])
    plt.imshow(data[k])
  plt.tight_layout()
  plt.show()


show(x_train , y_train)
# Out:
# <ipython-input-13-c83f3c050fbd>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,4, i+1)
# /usr/local/lib/python3.10/dist-packages/matplotlib/text.py:1279: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(512 , activation= 'relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(100, activation= 'softmax')

])

model.compile( optimizer= 'adamax',
              loss = 'sparse_categorical_crossentropy',
               metrics = ['accuracy'])

model.fit(x_train, y_train , epochs= 50)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 6s 3ms/step - loss: 4.3294 - accuracy: 0.0466
# Epoch 2/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 4.0278 - accuracy: 0.0848
# Epoch 3/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.8832 - accuracy: 0.1106
# Epoch 4/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.7912 - accuracy: 0.1256
# Epoch 5/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.7262 - accuracy: 0.1394
# Epoch 6/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.6704 - accuracy: 0.1485
# Epoch 7/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.6275 - accuracy: 0.1557
# Epoch 8/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.5829 - accuracy: 0.1635
# Epoch 9/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.5441 - accuracy: 0.1702
# Epoch 10/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.5121 - accuracy: 0.1744
# Epoch 11/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.4803 - accuracy: 0.1820
# Epoch 12/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.4488 - accuracy: 0.1875
# Epoch 13/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.4221 - accuracy: 0.1921
# Epoch 14/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.3974 - accuracy: 0.1947
# Epoch 15/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.3742 - accuracy: 0.2012
# Epoch 16/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.3485 - accuracy: 0.2039
# Epoch 17/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.3268 - accuracy: 0.2090
# Epoch 18/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.3056 - accuracy: 0.2134
# Epoch 19/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.2869 - accuracy: 0.2174
# Epoch 20/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.2643 - accuracy: 0.2201
# Epoch 21/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.2432 - accuracy: 0.2234
# Epoch 22/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.2213 - accuracy: 0.2297
# Epoch 23/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.2069 - accuracy: 0.2315
# Epoch 24/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.1892 - accuracy: 0.2353
# Epoch 25/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.1690 - accuracy: 0.2370
# Epoch 26/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.1560 - accuracy: 0.2446
# Epoch 27/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.1398 - accuracy: 0.2442
# Epoch 28/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.1190 - accuracy: 0.2477
# Epoch 29/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.1012 - accuracy: 0.2509
# Epoch 30/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.0905 - accuracy: 0.2517
# Epoch 31/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.0745 - accuracy: 0.2554
# Epoch 32/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.0565 - accuracy: 0.2605
# Epoch 33/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.0435 - accuracy: 0.2624
# Epoch 34/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.0296 - accuracy: 0.2654
# Epoch 35/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.0172 - accuracy: 0.2662
# Epoch 36/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 3.0060 - accuracy: 0.2682
# Epoch 37/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.9867 - accuracy: 0.2718
# Epoch 38/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.9764 - accuracy: 0.2759
# Epoch 39/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.9654 - accuracy: 0.2752
# Epoch 40/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.9535 - accuracy: 0.2779
# Epoch 41/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.9350 - accuracy: 0.2825
# Epoch 42/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.9313 - accuracy: 0.2829
# Epoch 43/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.9181 - accuracy: 0.2848
# Epoch 44/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.9027 - accuracy: 0.2877
# Epoch 45/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.8883 - accuracy: 0.2904
# Epoch 46/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.8882 - accuracy: 0.2906
# Epoch 47/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.8700 - accuracy: 0.2924
# Epoch 48/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.8574 - accuracy: 0.2970
# Epoch 49/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.8524 - accuracy: 0.2980
# Epoch 50/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.8418 - accuracy: 0.3000
# 313/313 [==============================] - 1s 2ms/step - loss: 3.2051 - accuracy: 0.2552
# [3.205141305923462, 0.25519999861717224]
